# %%
from coffea.nanoevents import NanoAODSchema
from coffea.dataset_tools import apply_to_fileset, max_chunks, max_files, preprocess

import dask

from analysis_tools.test_processor import SignalProcessor
# Out:
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Tue/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector

# %%
import gzip
import json
import os

# Define the base directory where the preprocessed files are stored
base_dir = "/eos/user/d/dgrove/Ph2_analysis/tools/preprocessing/preprocessed"
signal_sample = "2023_SlepSnu_MN1_270_100000_preprocessed_available.json.gz"
background_sample = "2023_ttbar_100000_preprocessed_available.json.gz"
signal_file_path = os.path.join(base_dir, signal_sample)
background_file_path = os.path.join(base_dir, background_sample)
#print(preprocessed)

with gzip.open(signal_file_path, "rt") as file:
    signal_preprocessed_available = json.load(file)
with gzip.open(background_file_path, "rt") as file:
    background_preprocessed_available = json.load(file)

# %%
signal_test_preprocessed_files = max_files(signal_preprocessed_available, 3)
signal_test_preprocessed = max_chunks(signal_test_preprocessed_files, 3)

### SWITCH HERE ###

signal_reduced_computation = True

###################

# signal

if signal_reduced_computation:
    small_tg, small_rep = apply_to_fileset(
        data_manipulation=SignalProcessor(),
        fileset=signal_test_preprocessed,
        schemaclass=NanoAODSchema,
        uproot_options={"allow_read_errors_with_report": (OSError, KeyError)},
    )
    signal_computed, rep = dask.compute(small_tg, small_rep)
    
else:
    full_tg, full_rep = apply_to_fileset(
        data_manipulation=SignalProcessor(),
        fileset=signal_preprocessed_available,
        schemaclass=NanoAODSchema,
        uproot_options={"allow_read_errors_with_report": (OSError, KeyError)},
    )
    signal_computed, rep = dask.compute(full_tg, full_rep)

# %%
sig_results = signal_computed['/SlepSnuCascade_MN1-270_MN2-280_MC1-275_TuneCP5_13p6TeV_madgraphMLM-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v6-v3/NANOAODSIM']

# %%
sig_results
# Out:
# {'counts': {'total_entries': 303452,
#   'count_ele': 228295,
#   'count_filtered_ele': 48104,
#   'count_cust_ele': 39955,
#   'count_disambig_ele': 34055,
#   'count_bronze_ele': 30584,
#   'count_full_bronze_test': 103367},
#  'calculations': {'ele_num': {'pfRelIso03_all': {(5, 6): 1391,
#     (6, 7): 1283,
#     (7, 8): 1206,
#     (8, 9): 1004,
#     (9, 10): 901,
#     (10, 11): 855,
#     (11, 12): 724,
#     (12, 13): 683,
#     (13, 14): 564,
#     (14, 15): 468,
#     (15, 20): 2304,
#     (20, 25): 2102,
#     (25, 30): 2267,
#     (30, 100): 14050},
#    'miniPFRelIso_all': {(5, 6): 1391,
#     (6, 7): 1283,
#     (7, 8): 1206,
#     (8, 9): 1004,
#     (9, 10): 901,
#     (10, 11): 855,
#     (11, 12): 724,
#     (12, 13): 683,
#     (13, 14): 564,
#     (14, 15): 468,
#     (15, 20): 2304,
#     (20, 25): 2102,
#     (25, 30): 2267,
#     (30, 100): 14050}}},
#  'plots': {'ele_mini_iso': Hist(Regular(100, 0, 50, name='mini_iso'), storage=Double()) # Sum: 228249.0 (228295.0 with flow),
#   'ele_mini_iso_zoom': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 226319.0 (228295.0 with flow),
#   'ele_pfrel_iso': Hist(Regular(100, 0, 50, name='pfrel_iso'), storage=Double()) # Sum: 228221.0 (228295.0 with flow),
#   'ele_pfrel_iso_zoom': Hist(Regular(100, 0, 10, name='pfrel_iso'), storage=Double()) # Sum: 226007.0 (228295.0 with flow),
#   'bronze_ele_mini_iso': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30584.0,
#   'bronze_ele_mini_iso_zoom': Hist(Regular(100, 0, 2, name='mini_iso'), storage=Double()) # Sum: 30584.0,
#   'bronze_ele_pfrel_iso': Hist(Regular(100, 0, 10, name='pfrel_iso'), storage=Double()) # Sum: 30584.0,
#   'bronze_ele_pfrel_iso_zoom': Hist(Regular(100, 0, 2, name='pfrel_iso'), storage=Double()) # Sum: 30584.0,
#   'bronze_ele_mini_iso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30522.0 (30584.0 with flow),
#   'bronze_ele_pfrel_iso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30559.0 (30584.0 with flow),
#   'bronze_ele_mini_iso_pt_5_10': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5779.0 (5785.0 with flow),
#   'bronze_ele_pfrel_iso_pt_5_10': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5785.0,
#   'bronze_ele_mini_iso_pt_10_15': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5779.0 (5785.0 with flow),
#   'bronze_ele_pfrel_iso_pt_10_15': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5785.0,
#   'gold_ele_pt': Hist(Regular(100, 0, 60, name='pt'), storage=Double()) # Sum: 17049.0 (20207.0 with flow),
#   'gold_ele_eta': Hist(Regular(100, -3, 3, name='eta'), storage=Double()) # Sum: 20207.0,
#   'gold_ele_sip3d': Hist(Regular(100, 0, 10, name='sip3d'), storage=Double()) # Sum: 20207.0,
#   'gold_ele_miniiso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 20207.0,
#   'gold_ele_reliso_pt': Hist(Regular(100, 0, 10, name='rel_iso'), storage=Double()) # Sum: 20207.0,
#   'gole_ele_cutbased': Hist(Regular(100, 0, 10, name='cutbased'), storage=Double()) # Sum: 20207.0},
#  'tests': {'count_gold_ele': 20207, 'count_silver_ele': 3068}}

# %%
sig_counts = sig_results["counts"] 
sig_counts
# Out:
# {'total_entries': 303452,
#  'count_ele': 228295,
#  'count_filtered_ele': 48104,
#  'count_cust_ele': 39955,
#  'count_disambig_ele': 34055,
#  'count_bronze_ele': 30584,
#  'count_full_bronze_test': 103367}

# %%
count_ele = sig_counts["count_ele"]
count_bronze_ele = sig_counts["count_bronze_ele"]

# %%
sig_plots = sig_results["plots"] 
sig_plots
# Out:
# {'ele_mini_iso': Hist(Regular(100, 0, 50, name='mini_iso'), storage=Double()) # Sum: 228249.0 (228295.0 with flow),
#  'ele_mini_iso_zoom': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 226319.0 (228295.0 with flow),
#  'ele_pfrel_iso': Hist(Regular(100, 0, 50, name='pfrel_iso'), storage=Double()) # Sum: 228221.0 (228295.0 with flow),
#  'ele_pfrel_iso_zoom': Hist(Regular(100, 0, 10, name='pfrel_iso'), storage=Double()) # Sum: 226007.0 (228295.0 with flow),
#  'bronze_ele_mini_iso': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30584.0,
#  'bronze_ele_mini_iso_zoom': Hist(Regular(100, 0, 2, name='mini_iso'), storage=Double()) # Sum: 30584.0,
#  'bronze_ele_pfrel_iso': Hist(Regular(100, 0, 10, name='pfrel_iso'), storage=Double()) # Sum: 30584.0,
#  'bronze_ele_pfrel_iso_zoom': Hist(Regular(100, 0, 2, name='pfrel_iso'), storage=Double()) # Sum: 30584.0,
#  'bronze_ele_mini_iso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30522.0 (30584.0 with flow),
#  'bronze_ele_pfrel_iso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 30559.0 (30584.0 with flow),
#  'bronze_ele_mini_iso_pt_5_10': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5779.0 (5785.0 with flow),
#  'bronze_ele_pfrel_iso_pt_5_10': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5785.0,
#  'bronze_ele_mini_iso_pt_10_15': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5779.0 (5785.0 with flow),
#  'bronze_ele_pfrel_iso_pt_10_15': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 5785.0,
#  'gold_ele_pt': Hist(Regular(100, 0, 60, name='pt'), storage=Double()) # Sum: 17049.0 (20207.0 with flow),
#  'gold_ele_eta': Hist(Regular(100, -3, 3, name='eta'), storage=Double()) # Sum: 20207.0,
#  'gold_ele_sip3d': Hist(Regular(100, 0, 10, name='sip3d'), storage=Double()) # Sum: 20207.0,
#  'gold_ele_miniiso_pt': Hist(Regular(100, 0, 10, name='mini_iso'), storage=Double()) # Sum: 20207.0,
#  'gold_ele_reliso_pt': Hist(Regular(100, 0, 10, name='rel_iso'), storage=Double()) # Sum: 20207.0,
#  'gole_ele_cutbased': Hist(Regular(100, 0, 10, name='cutbased'), storage=Double()) # Sum: 20207.0}

# %%
import matplotlib.pyplot as plt
import mplhep

# %%
#have to call this a second time to get proper scaling, a known bug
mplhep.style.use(mplhep.style.CMS)
plt.figure()
mplhep.style.use(mplhep.style.CMS)

# %%
"""
plt.figure()
fig, ax = plt.subplots(figsize=(10, 6))

ele_mini_iso = sig_plots["ele_mini_iso"]
#ele_count = sig_plots["count_ele"]

ele_mini_iso.plot1d(ax=ax, label="SlepSnu 270")
entries = ele_mini_iso.sum()

plt.xlabel("miniPFRelIso")
plt.ylabel("Counts")
plt.yscale("log")

ax.text(
    0.95, 0.8,  # Position in axis coordinates (1=top right, 0=bottom left)
    f"Entries: {int(entries)}", 
    transform=ax.transAxes,  # Ensures coordinates are relative to the axis
    fontsize=15,
    verticalalignment="top",
    horizontalalignment="right",
    bbox=dict(facecolor='white', alpha=0.5, edgecolor='black')  # Add a background box
)

#ax.axvline(x=5, color='black', linestyle=':', linewidth=2)
plt.title("electrons: miniPFRelIso_all (no cuts)", pad=25)  # Adjust title position
mplhep.cms.label(loc=0, fontsize=15)  # Move CMS label to a different position
plt.legend()

print(f"Total histogram entries: {entries}")
"""
# Out:
# '\nplt.figure()\nfig, ax = plt.subplots(figsize=(10, 6))\n\nele_mini_iso = sig_plots["ele_mini_iso"]\n#ele_count = sig_plots["count_ele"]\n\nele_mini_iso.plot1d(ax=ax, label="SlepSnu 270")\nentries = ele_mini_iso.sum()\n\nplt.xlabel("miniPFRelIso")\nplt.ylabel("Counts")\nplt.yscale("log")\n\nax.text(\n    0.95, 0.8,  # Position in axis coordinates (1=top right, 0=bottom left)\n    f"Entries: {int(entries)}", \n    transform=ax.transAxes,  # Ensures coordinates are relative to the axis\n    fontsize=15,\n    verticalalignment="top",\n    horizontalalignment="right",\n    bbox=dict(facecolor=\'white\', alpha=0.5, edgecolor=\'black\')  # Add a background box\n)\n\n#ax.axvline(x=5, color=\'black\', linestyle=\':\', linewidth=2)\nplt.title("electrons: miniPFRelIso_all (no cuts)", pad=25)  # Adjust title position\nmplhep.cms.label(loc=0, fontsize=15)  # Move CMS label to a different position\nplt.legend()\n\nprint(f"Total histogram entries: {entries}")\n'

# %%
"""
def plot_all_histograms(hist_dict, dataset_label="SlepSnu 270"):
    
    for hist_name, hist_obj in hist_dict.items():
        plt.figure()
        fig, ax = plt.subplots(figsize=(10, 6))

        # Plot histogram
        hist_obj.plot1d(ax=ax, label=dataset_label)

        # Compute total entries
        total_entries = hist_obj.sum()

        # Add text annotation for total count inside the plot
        ax.text(
            0.95, 0.8,  # Position in axis coordinates (1=top right, 0=bottom left)
            f"Entries: {int(total_entries)}", 
            transform=ax.transAxes,  
            fontsize=15,
            verticalalignment="top",
            horizontalalignment="right",
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='black')  
        )

        # Labels and formatting
        plt.xlabel(hist_name.replace("_", " "))  # Format variable name as label
        plt.ylabel("Counts")
        plt.yscale("log")
        plt.title(f"{hist_name} Distribution", pad=25)
        
        # CMS label
        mplhep.cms.label(loc=0, fontsize=15)

        plt.legend()
        plt.show()

        # Print total entries for debugging
        print(f"Total histogram entries for {hist_name}: {int(total_entries)}")
"""
# Out:
# '\ndef plot_all_histograms(hist_dict, dataset_label="SlepSnu 270"):\n    \n    for hist_name, hist_obj in hist_dict.items():\n        plt.figure()\n        fig, ax = plt.subplots(figsize=(10, 6))\n\n        # Plot histogram\n        hist_obj.plot1d(ax=ax, label=dataset_label)\n\n        # Compute total entries\n        total_entries = hist_obj.sum()\n\n        # Add text annotation for total count inside the plot\n        ax.text(\n            0.95, 0.8,  # Position in axis coordinates (1=top right, 0=bottom left)\n            f"Entries: {int(total_entries)}", \n            transform=ax.transAxes,  \n            fontsize=15,\n            verticalalignment="top",\n            horizontalalignment="right",\n            bbox=dict(facecolor=\'white\', alpha=0.5, edgecolor=\'black\')  \n        )\n\n        # Labels and formatting\n        plt.xlabel(hist_name.replace("_", " "))  # Format variable name as label\n        plt.ylabel("Counts")\n        plt.yscale("log")\n        plt.title(f"{hist_name} Distribution", pad=25)\n        \n        # CMS label\n        mplhep.cms.label(loc=0, fontsize=15)\n\n        plt.legend()\n        plt.show()\n\n        # Print total entries for debugging\n        print(f"Total histogram entries for {hist_name}: {int(total_entries)}")\n'

# %%
#plot_all_histograms(sig_plots)

# %%
import matplotlib.pyplot as plt
import mplhep
import os

mplhep.style.use(mplhep.style.CMS)

def plot_all_histograms(hist_dict, dataset_label="SlepSnu 270", save_dir="hist_plots", save_format="png"):
    """
    Loops through a dictionary of histograms, generates plots, and saves them.

    Parameters:
    - hist_dict: dict -> Dictionary containing histograms.
    - dataset_label: str -> Label for legend (default: "SlepSnu 270").
    - save_dir: str -> Directory where plots will be saved (default: "hist_plots").
    - save_format: str -> Image format (default: "png"). Can be "png", "pdf", etc.
    """

    # Ensure the directory exists
    os.makedirs(save_dir, exist_ok=True)

    for hist_name, hist_obj in hist_dict.items():
        plt.figure()
        fig, ax = plt.subplots(figsize=(10, 6))

        # Plot histogram
        hist_obj.plot1d(ax=ax, label=dataset_label)

        # Compute total entries
        total_entries = hist_obj.sum()

        # Add text annotation for total count inside the plot
        ax.text(
            0.95, 0.8,  
            f"Entries: {int(total_entries)}", 
            transform=ax.transAxes,  
            fontsize=15,
            verticalalignment="top",
            horizontalalignment="right",
            bbox=dict(facecolor='white', alpha=0.5, edgecolor='black')  
        )

        # Labels and formatting
        plt.xlabel(hist_name.replace("_", " "))  
        plt.ylabel("Counts")
        plt.yscale("log")
        plt.title(f"{hist_name} Distribution", pad=25)
        
        # CMS label
        mplhep.cms.label(loc=0, fontsize=15)

        plt.legend()

        # Save plot to file
        save_path = os.path.join(save_dir, f"{hist_name}.{save_format}")
        plt.savefig(save_path, dpi=300, bbox_inches="tight")  # High-quality save

        # Show plot
        plt.show()

        # Print total entries for debugging
        print(f"Total histogram entries for {hist_name}: {int(total_entries)}")

# %%
plot_all_histograms(sig_plots)
# Out:
# Total histogram entries for ele_mini_iso: 228249
# Total histogram entries for ele_mini_iso_zoom: 226319
# Total histogram entries for ele_pfrel_iso: 228221
# Total histogram entries for ele_pfrel_iso_zoom: 226007
# Total histogram entries for bronze_ele_mini_iso: 30584
# Total histogram entries for bronze_ele_mini_iso_zoom: 30584
# Total histogram entries for bronze_ele_pfrel_iso: 30584
# Total histogram entries for bronze_ele_pfrel_iso_zoom: 30584
# Total histogram entries for bronze_ele_mini_iso_pt: 30522
# Total histogram entries for bronze_ele_pfrel_iso_pt: 30559
# Total histogram entries for bronze_ele_mini_iso_pt_5_10: 5779
# Total histogram entries for bronze_ele_pfrel_iso_pt_5_10: 5785
# Total histogram entries for bronze_ele_mini_iso_pt_10_15: 5779
# Total histogram entries for bronze_ele_pfrel_iso_pt_10_15: 5785
# Total histogram entries for gold_ele_pt: 17049
# Total histogram entries for gold_ele_eta: 20207
# Total histogram entries for gold_ele_sip3d: 20207
# Total histogram entries for gold_ele_miniiso_pt: 20207
# Total histogram entries for gold_ele_reliso_pt: 20207
# Total histogram entries for gole_ele_cutbased: 20207
