# %%
# BEFORE RUNNING: Must initiate proxy in terminal with voms-proxy-init -voms cms -rfc --valid 168:0
# We will start this tool with a simple import of the datasets.json:

import json

from coffea.dataset_tools import rucio_utils
from coffea.dataset_tools.dataset_query import print_dataset_query
from rich.console import Console
from coffea.dataset_tools.dataset_query import DataDiscoveryCLI



with open("datasets.json", "r") as file:
    datasets = json.load(file)

for year, samples in datasets.items():
    for metadata in samples.values():
        print(metadata["DAS_path"])
    
chunk_size = 100000

for year, sample in datasets.items():
    for sample_name, metadata in sample.items():  # Extract sample_name properly
        file_name = f"preprocessed/{year}_{sample_name}_{str(chunk_size)}_preprocessed"  # Corrected filename
        DAS_path = metadata["DAS_path"]
        ddc = DataDiscoveryCLI()
        ddc.do_query(DAS_path)
        ddc.do_select("all")
        ddc.do_list_selected()
        #ddc.do_regex_sites(r"T[12]_(US)_\w+")
        ddc.do_replicas("first", "all")
        
        fileset_total = ddc.do_preprocess(output_file=file_name,
            step_size = chunk_size,  #chunk size for files splitting
            align_to_clusters=False,
            recalculate_steps=False,
            files_per_batch=1,
            save_form=True,
            scheduler_url=None)
# Out:
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# Output()
# /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc2017_realistic_v9-v1/NANOAODSIM
# /SlepSnuCascade_MN1-220_MN2-260_MC1-240_TuneCP5_13p6TeV_madgraphMLM-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v6-v3/NANOAODSIM
# /SlepSnuCascade_MN1-260_MN2-280_MC1-270_TuneCP5_13p6TeV_madgraphMLM-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v6-v3/NANOAODSIM
# /SlepSnuCascade_MN1-270_MN2-280_MC1-275_TuneCP5_13p6TeV_madgraphMLM-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v6-v3/NANOAODSIM
# /TTto2L2Nu_TuneCP5_13p6TeV_powheg-pythia8/Run3Summer23NanoAODv12-130X_mcRun3_2023_realistic_v14-v2/NANOAODSIM
# /WZ_TuneCP5_13p6TeV_pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v2-v2/NANOAODSIM
# /WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v2-v3/NANOAODSIM
# /WW_TuneCP5_13p6TeV_pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v2-v2/NANOAODSIM
# /DYto2L-2Jets_MLL-10to50_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v2_ext1-v3/NANOAODSIM
#                                                       Query:
# /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┓
# ┃ Name                                        ┃ Tag                                                              ┃┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇┩
# │ TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-py… │ (1) RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANO… ││
# └─────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────┴┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Use the command select to selected the datasets
# Selected datasets:
# - (1)
# /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# Selected datasets:
#                                                  Selected datasets
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┳┓
# ┃ … ┃ Dataset                                                                                                   ┃┃┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇╇┩
# │ 1 │ /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/… │││
# └───┴───────────────────────────────────────────────────────────────────────────────────────────────────────────┴┴┘
# Loading SITECONF info
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sites availability for dataset:
# /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
#                  Available replicas
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Index ┃ Site             ┃ Files   ┃ Availability ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │   0   │ T1_DE_KIT_Disk   │ 66 / 66 │    100.0%    │
# │   1   │ T3_US_FNALLPC    │ 66 / 66 │    100.0%    │
# │   2   │ T2_KR_KISTI      │ 66 / 66 │    100.0%    │
# │   3   │ T2_UK_London_IC  │ 66 / 66 │    100.0%    │
# │   4   │ T3_KR_UOS        │ 66 / 66 │    100.0%    │
# │   5   │ T1_US_FNAL_Disk  │ 50 / 66 │    75.8%     │
# │   6   │ T1_IT_CNAF_Disk  │ 32 / 66 │    48.5%     │
# │   7   │ T2_US_Florida    │ 21 / 66 │    31.8%     │
# │   8   │ T2_US_MIT        │ 12 / 66 │    18.2%     │
# │   9   │ T2_US_Wisconsin  │ 12 / 66 │    18.2%     │
# │  10   │ T2_US_Nebraska   │ 11 / 66 │    16.7%     │
# │  11   │ T2_US_Purdue     │ 9 / 66  │    13.6%     │
# │  12   │ T2_US_Vanderbilt │ 8 / 66  │    12.1%     │
# │  13   │ T1_ES_PIC_Disk   │ 6 / 66  │     9.1%     │
# │  14   │ T2_IT_Legnaro    │ 6 / 66  │     9.1%     │
# │  15   │ T2_DE_RWTH       │ 5 / 66  │     7.6%     │
# │  16   │ T2_TR_METU       │ 4 / 66  │     6.1%     │
# │  17   │ T2_US_UCSD       │ 4 / 66  │     6.1%     │
# │  18   │ T2_ES_CIEMAT     │ 4 / 66  │     6.1%     │
# │  19   │ T2_BR_SPRACE     │ 3 / 66  │     4.5%     │
# │  20   │ T2_ES_IFCA       │ 3 / 66  │     4.5%     │
# │  21   │ T2_BE_IIHE       │ 2 / 66  │     3.0%     │
# │  22   │ T2_US_Caltech    │ 2 / 66  │     3.0%     │
# └───────┴──────────────────┴─────────┴──────────────┘
# Replicas for
# /TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# ├── T1_US_FNAL_Disk
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/2820000/25C8DD83-C32E-D746-9049-98DAEDA73CF7.r
# │   │   oot
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/2820000/5457F199-A129-2A40-8127-733D51A9A3E6.r
# │   │   oot
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/2820000/838E6251-D257-E54A-B82C-0BD681975B86.r
# │   │   oot
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/040206C8-D83C-BA42-BE3F-C3CB0920BEED.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/0C483F40-C7FA-0445-B1A0-0C90E2450527.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/157E80A8-87A7-A648-84C3-DD941BFA1D7C.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/1DA1E53F-DCA9-BE49-BAE2-7AA2D6FDA7B4.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/251D4E82-949F-E944-8C47-2C8FC3CBEBFA.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/25600B4C-6405-F448-9CD3-91EB3B33A114.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/466940CB-5EBC-B34C-B650-940FBF469D07.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/5AB854B1-1DB6-174F-8B0A-E4725A80994C.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/5EA5D32D-1ECE-564B-9EC5-C003828D9145.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/655344C6-05B2-5D46-A608-F589CC600881.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/6AF3BAC7-B767-044A-8801-4A81E3A80BF4.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/87EE7BE7-2EF3-6E46-974F-FE76BC6DA5BC.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/8D296C2D-E556-3E4B-A5CB-F3035351C313.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/9238E966-B452-3143-A0FB-9363665BF587.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/935FB2F0-EE0B-F445-8A64-5EEFD277BF20.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/9A8C30C2-5E17-1040-A4E4-5D7C8BB0081F.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/A1F0A088-0931-3140-9B33-2B4FB99F8BBD.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/B188292A-75B9-4440-9CD8-98D416426499.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/C2576185-9A33-954A-AE97-9D2E48056296.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/C3C566A1-5689-854B-8B52-2A00C841677D.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/D17A9ED0-B887-8F4B-9480-28F00D53CE44.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/F65C097C-C70B-5F40-B5D1-56D230DB64C5.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/137AD65A-3E27-3240-B4D7-15D63624B703.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/1A825C77-7998-F445-BAC6-F5ED8F2347D2.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/2C33E603-E710-E648-92D6-506149EF2EF9.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/2FB29631-6B68-C640-A68C-CB15E697CD5A.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/36D0E49B-1FA1-854D-92D6-058CA66931D7.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/4D5A89C1-1F3E-1E4F-B932-3C73F032140E.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/6481B941-20E1-EC49-A059-E986B3C09DEB.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/6689D674-3E2E-F741-8F27-62D6FBF41EF9.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/75CB6752-05D5-5747-8F6B-3B368459B701.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/76D33496-D03B-7D4B-A34E-A8DC728B912D.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/7A72DEE9-DF82-2F4B-9D7F-1BBFA2C80696.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/7DC5D661-420D-994E-8CE8-4F1F4D2CFDBB.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/881206CE-DCE1-964C-B168-6EE491F29AC3.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/8FC89895-4717-BE46-AB30-9E862A7F0EB4.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/BDB9B4D0-4BEA-8447-AEA6-6953F652F285.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/CD457AC4-ADD4-864A-82F6-B801DC396174.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/D1473181-6977-A546-8E44-1C6585E8543E.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/D1BF1E97-5B7B-5E42-A0DD-1DEB1493302E.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/D282A789-EED0-1641-A5AB-FB871A2C4E39.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/D3AFBB13-C368-6C49-8A55-E8AD5EEEC7AE.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/DC7407F2-32E3-7546-BCA1-F3E45C0AA8DF.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/DF68DFBA-FC52-7248-8837-1073A83553A7.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/EC0743F4-AC25-BC40-AE11-ACA537848A32.roo
# │   │   t
# │   ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │   │   V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/F3DB7513-9011-3D42-BA38-7CFB4BB58CD1.roo
# │   │   t
# │   └── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13Te
# │       V-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/FB69BFDF-ADD5-8944-AA33-681E611906DC.roo
# │       t
# └── T1_DE_KIT_Disk
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/342DA03F-4FBC-2E42-B44D-880B6818075C.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/B9037E7F-9158-114E-B725-6162182415A4.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/40000/F91CF867-79D3-DF4A-B1A6-0D3CE6FE050C.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/12D57CAF-00C5-484F-B744-5BA50CDC7540.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/1961FF79-AA32-D94F-BD7F-303E6ED6131F.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/1B7BE261-DE25-1842-8349-646B3D9D3EA1.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/238B3428-FA33-9143-8D9E-01AB528645ED.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/4D6FC96D-C6C4-6346-85CE-7122CF84FBA8.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/65794807-7D39-5A4B-9907-4E378824A488.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/7C86E4E9-D1B8-E74D-B833-707229FD0558.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/937EED08-8A6E-9048-90C0-139F4907B43D.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/BD0AC8FE-F3C7-9846-B5E5-DFE00F4BBBD3.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/D9B4F874-366A-A347-A0C3-D4BFE122A7A4.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/ECC7C9BE-62C3-7B47-8A8F-5751BF69C795.root
#     ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#     │   adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/F6D00887-22E0-CC42-A669-1081C3AD1FA0.root
#     └── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/TTJets_DiLept_TuneCP5_13TeV-m
#         adgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/50000/F866BE75-2905-8E43-AB5F-FCE1F9FE0D8E.root
# Output()
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved available fileset chunks to preprocessed/2017_ttbar_100000_preprocessed_available.json.gz
# Saved all fileset chunks to preprocessed/2017_ttbar_100000_preprocessed_all.json.gz
# Output()
#       Query: /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━┓
# ┃ Name                     ┃ Tag                                                                   ┃ Selected ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━┩
# │ WZ_TuneCP5_13TeV-pythia8 │ (1) RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM │    N     │
# └──────────────────────────┴───────────────────────────────────────────────────────────────────────┴──────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Use the command select to selected the datasets
# Selected datasets:
# - (1) /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# Selected datasets:
#                                                  Selected datasets
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━━━┓
# ┃       ┃                                                                                             ┃     ┃ N.  ┃
# ┃       ┃                                                                                             ┃ Re… ┃ of  ┃
# ┃ Index ┃ Dataset                                                                                     ┃ se… ┃ fi… ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━╇━━━━━┩
# │ 1     │ /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM │  N  │  -  │
# └───────┴─────────────────────────────────────────────────────────────────────────────────────────────┴─────┴─────┘
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sites availability for dataset:
# /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
#                  Available replicas
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Index ┃ Site             ┃ Files   ┃ Availability ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │   0   │ T2_DE_DESY       │ 20 / 20 │    100.0%    │
# │   1   │ T3_KR_KISTI      │ 20 / 20 │    100.0%    │
# │   2   │ T3_US_FNALLPC    │ 20 / 20 │    100.0%    │
# │   3   │ T2_IT_Legnaro    │ 20 / 20 │    100.0%    │
# │   4   │ T2_KR_KISTI      │ 20 / 20 │    100.0%    │
# │   5   │ T2_EE_Estonia    │ 20 / 20 │    100.0%    │
# │   6   │ T2_ES_CIEMAT     │ 20 / 20 │    100.0%    │
# │   7   │ T3_US_NotreDame  │ 20 / 20 │    100.0%    │
# │   8   │ T3_CH_PSI        │ 20 / 20 │    100.0%    │
# │   9   │ T3_KR_UOS        │ 20 / 20 │    100.0%    │
# │  10   │ T2_US_Wisconsin  │ 18 / 20 │    90.0%     │
# │  11   │ T1_US_FNAL_Disk  │ 13 / 20 │    65.0%     │
# │  12   │ T2_US_Nebraska   │ 8 / 20  │    40.0%     │
# │  13   │ T2_US_MIT        │ 4 / 20  │    20.0%     │
# │  14   │ T2_US_Vanderbilt │ 3 / 20  │    15.0%     │
# │  15   │ T2_US_Florida    │ 3 / 20  │    15.0%     │
# │  16   │ T2_US_Purdue     │ 3 / 20  │    15.0%     │
# │  17   │ T2_DE_RWTH       │ 3 / 20  │    15.0%     │
# │  18   │ T2_BE_IIHE       │ 3 / 20  │    15.0%     │
# │  19   │ T2_US_Caltech    │ 2 / 20  │    10.0%     │
# │  20   │ T2_ES_IFCA       │ 1 / 20  │     5.0%     │
# │  21   │ T1_IT_CNAF_Disk  │ 1 / 20  │     5.0%     │
# │  22   │ T2_TR_METU       │ 1 / 20  │     5.0%     │
# │  23   │ T2_PT_NCG_Lisbon │ 1 / 20  │     5.0%     │
# │  24   │ T2_US_UCSD       │ 1 / 20  │     5.0%     │
# └───────┴──────────────────┴─────────┴──────────────┘
# Replicas for /WZ_TuneCP5_13TeV-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v1/NANOAODSIM
# ├── T2_DE_DESY
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/120000/3032CE7C-FDDE-7243-8B89-13AD7549A797.root
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/130000/4563AB48-B968-8E40-A2B6-CC2267F666FD.root
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/270000/57183F7B-DFD4-2F4A-8D0E-30146B8180B3.root
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/280000/2324A46E-D508-F64E-A349-47B2C32F9DF9.root
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/280000/6AE90AAD-6FF4-9045-A6D2-C49FC51EE04F.root
# │   ├── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │   │   SIM/106X_mc2017_realistic_v9-v1/280000/EF9CBF4E-A9FC-ED44-B5FF-EA26470BD4A0.root
# │   └── root://dcache-cms-xrootd.desy.de:1094//store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/NANOAOD
# │       SIM/106X_mc2017_realistic_v9-v1/70000/A454D9FC-0C9F-6143-9992-4A52ED757887.root
# └── T1_US_FNAL_Disk
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/120000/936C5557-15D6-B74C-9260-582B71C8B1C3.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/120000/E4F05A6C-CBDD-254C-ABBD-38B7A5E81EB3.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/270000/34A260AF-5CF4-5648-BF9F-B84B7A5F2859.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/57CF3855-EDA0-D74A-95AF-BE11A0C5CC47.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/77F8F67B-C473-C24E-9457-CAA86B73C08F.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/8B3F8D35-772E-8A4A-A5DC-1C210FE634B9.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/A474C122-CA95-614C-9B59-9B59E4434863.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/BB9C5117-3695-A84C-AE4A-B50DF2A5A493.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/C7D7623B-2820-3B4E-AEA4-7062EC204912.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/280000/D7187C96-49C4-FE47-A9D1-919C7155E553.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/70000/5CDC101C-4B0C-D248-B7DE-D3A4603F2D67.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#     │   ANOAODSIM/106X_mc2017_realistic_v9-v1/70000/A8308F60-1073-D742-B102-713C001C89AB.root
#     └── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/WZ_TuneCP5_13TeV-pythia8/N
#         ANOAODSIM/106X_mc2017_realistic_v9-v1/70000/AA222480-64FA-2140-B920-4606F5772B4C.root
# Output()
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved available fileset chunks to preprocessed/2017_WZ_100000_preprocessed_available.json.gz
# Saved all fileset chunks to preprocessed/2017_WZ_100000_preprocessed_all.json.gz
# Output()
#                                                       Query:
# /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v
#                                                    1/NANOAODSIM
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┓
# ┃ Name                                              ┃ Tag                                                        ┃┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇┩
# │ SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgrap… │ (1) RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v… ││
# └───────────────────────────────────────────────────┴────────────────────────────────────────────────────────────┴┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Use the command select to selected the datasets
# Selected datasets:
# - (1)
# /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v
# 1/NANOAODSIM
# Selected datasets:
#                                                  Selected datasets
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┳┓
# ┃ … ┃ Dataset                                                                                                   ┃┃┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇╇┩
# │ 1 │ /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_rea… │││
# └───┴───────────────────────────────────────────────────────────────────────────────────────────────────────────┴┴┘
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sites availability for dataset:
# /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v
# 1/NANOAODSIM
#                   Available replicas
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Index ┃ Site               ┃ Files   ┃ Availability ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━┩
# │   0   │ T1_US_FNAL_Disk    │ 20 / 20 │    100.0%    │
# │   1   │ T1_FR_CCIN2P3_Disk │ 20 / 20 │    100.0%    │
# │   2   │ T1_DE_KIT_Disk     │ 20 / 20 │    100.0%    │
# │   3   │ T1_IT_CNAF_Disk    │ 20 / 20 │    100.0%    │
# │   4   │ T2_US_MIT          │ 19 / 20 │    95.0%     │
# │   5   │ T2_IN_TIFR         │ 19 / 20 │    95.0%     │
# │   6   │ T2_BR_SPRACE       │ 1 / 20  │     5.0%     │
# │   7   │ T2_EE_Estonia      │ 1 / 20  │     5.0%     │
# └───────┴────────────────────┴─────────┴──────────────┘
# Replicas for
# /SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-106X_mc2017_realistic_v9-v
# 1/NANOAODSIM
# └── T1_US_FNAL_Disk
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/0B041116-DADF-CF45-8C16-DF2
#     │   920CC756D.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/1D4A080A-4230-7D44-BC89-756
#     │   9261BDEB7.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/24CC610C-2F7E-C64D-AF51-48C
#     │   CDF98DE28.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/42F85F0D-CD12-414D-A062-EA1
#     │   6FBECBE74.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/44B9EBA2-3644-EC4A-A65E-935
#     │   C0B61580E.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/4D98C063-E7AF-7149-B949-3A4
#     │   A5EA39C99.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/67A2A2BE-E1A8-344D-A896-B03
#     │   BF75B0B84.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/67CFF839-B38C-CC4B-ABEA-3E5
#     │   64508B7A3.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/6AA32610-70F2-8040-92E3-2FC
#     │   92B4E967B.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/86CF4FED-D3AC-A74F-9D28-49B
#     │   086F858ED.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/8B406AA8-F64D-C84D-87DF-F89
#     │   BED7E278E.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/93541E04-AA9A-7940-B39D-B5D
#     │   E3C8A131E.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/9D7E73D6-D934-7D45-8E4E-8CD
#     │   C67B70692.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/A7D92860-74C2-AD47-A625-ECD
#     │   9E8BB1EBC.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/AA85A4D4-8FAF-9149-BDCC-0D5
#     │   C5830CE83.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/AE2F696A-8239-0949-9900-EF7
#     │   5B0E2EC79.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/C593606E-E032-034F-8369-A73
#     │   240B7602A.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/D0F0D7F1-46D4-7346-AE73-622
#     │   6164D2A8B.root
#     ├── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#     │   _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/F21A67FC-48FD-E347-BF65-8CD
#     │   0269EDE1B.root
#     └── root://cmsdcadisk.fnal.gov//dcache/uscmsdisk/store/mc/RunIISummer20UL17NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1
#         _TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_mc2017_realistic_v9-v1/80000/FEFBCD38-C2E8-A84B-8D0D-520
#         6F848C282.root
# Output()
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Saved available fileset chunks to preprocessed/2017_TChiWZ_100000_preprocessed_available.json.gz
# Saved all fileset chunks to preprocessed/2017_TChiWZ_100000_preprocessed_all.json.gz
# Output()
#                                                       Query:
# /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc201
#                                            7_realistic_v9-v1/NANOAODSIM
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┓
# ┃ Name                                        ┃ Tag                                                              ┃┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇┩
# │ SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV… │ (1) RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc2017_realis… ││
# └─────────────────────────────────────────────┴──────────────────────────────────────────────────────────────────┴┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Use the command select to selected the datasets
# Selected datasets:
# - (1)
# /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc201
# 7_realistic_v9-v1/NANOAODSIM
# Selected datasets:
#                                                  Selected datasets
# ┏━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳┳┓
# ┃ … ┃ Dataset                                                                                                   ┃┃┃
# ┡━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇╇┩
# │ 1 │ /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17… │││
# └───┴───────────────────────────────────────────────────────────────────────────────────────────────────────────┴┴┘
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sites availability for dataset:
# /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc201
# 7_realistic_v9-v1/NANOAODSIM
#                 Available replicas
# ┏━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━┓
# ┃ Index ┃ Site             ┃ Files ┃ Availability ┃
# ┡━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━┩
# │   0   │ T1_DE_KIT_Disk   │ 5 / 5 │    100.0%    │
# │   1   │ T2_RU_JINR       │ 5 / 5 │    100.0%    │
# │   2   │ T2_UK_London_IC  │ 5 / 5 │    100.0%    │
# │   3   │ T2_US_UCSD       │ 4 / 5 │    80.0%     │
# │   4   │ T1_ES_PIC_Disk   │ 4 / 5 │    80.0%     │
# │   5   │ T2_BR_SPRACE     │ 4 / 5 │    80.0%     │
# │   6   │ T1_US_FNAL_Disk  │ 1 / 5 │    20.0%     │
# │   7   │ T2_US_Vanderbilt │ 1 / 5 │    20.0%     │
# └───────┴──────────────────┴───────┴──────────────┘
# Replicas for
# /SMS-TSlepSlep_mSlep-100To475_TuneCP5_13TeV-madgraphMLM-pythia8/RunIISummer20UL17NanoAODv9-FSUL17_FSUL17_106X_mc201
# 7_realistic_v9-v1/NANOAODSIM
# ├── T1_DE_KIT_Disk
# │   ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/SMS-TSlepSlep_mSlep-100To475_
# │   │   TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/FSUL17_FSUL17_106X_mc2017_realistic_v9-v1/50000/5244169E-4F18-
# │   │   F649-BE1C-C327F93D668C.root
# │   ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/SMS-TSlepSlep_mSlep-100To475_
# │   │   TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/FSUL17_FSUL17_106X_mc2017_realistic_v9-v1/50000/78B9FAED-5A2C-
# │   │   7540-89F0-507185DF146D.root
# │   ├── root://cmsdcache-kit-disk.gridka.de:1094//store/mc/RunIISummer20UL17NanoAODv9/SMS-TSlepSlep_mSlep-100To475_
# │   │   TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/FSUL17_FSUL17_106X_mc2017_realistic_v9-v1/50000/CAD43160-4DB5-
# │   │   5445-A0B3-C88CCAC73F61.root
# ...
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/a99cb64e-d6aa-479
#     │   2-b88b-2f106a7e25af.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/adb1c3ec-e0ac-495
#     │   6-866c-a51330547d60.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b013b078-269e-45b
#     │   f-9e8b-93e812ef0c7f.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b0216c60-7ae6-4e8
#     │   3-b79e-5449894ece26.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b20740fd-f611-455
#     │   7-a851-600fa5ff220a.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b228e3db-cf7c-43e
#     │   8-9d62-48adf7cd7a42.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b9464724-a543-461
#     │   e-ad3b-5120ba6f9290.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/b9c56db6-af0c-41f
#     │   1-a6cc-c193cdc8f24a.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/bdf77a2b-03d4-494
#     │   4-83c6-1b3abc78dc21.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/c1c44158-cd50-4bb
#     │   1-a4d6-f4acdb40d8e6.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/c212b1d6-8762-465
#     │   d-99bf-458d4ca43bd3.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/c23e6b33-e24a-416
#     │   e-a2cf-2bf93ad56247.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/c48d04f9-8c4f-462
#     │   3-8ebe-4446c8df80ab.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/cc9f7834-2c71-444
#     │   a-bc5a-734e049d273a.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/d5a89780-2272-419
#     │   4-a2c5-ff79dd5e76cd.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/de4455d2-5968-44d
#     │   4-9dab-eda890f3d359.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/dff70fda-b7fb-4db
#     │   f-aaee-3640e3aed731.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e0d46e76-d121-434
#     │   6-84d4-25c5bdfd5104.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e0dbbc44-fb7f-428
#     │   6-9285-f407ac5b8502.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e28e0265-7884-4f1
#     │   d-96a0-515fd2f2158d.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e3775495-b2f2-45d
#     │   7-a55b-728f32453fa2.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e8de16bc-062a-40a
#     │   d-ab30-c7be49c24dd2.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/e96f6069-d3d7-425
#     │   f-a2a2-7f4ced708a4b.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/ea34cd50-a94b-48e
#     │   9-b1ad-0f3b307313db.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/eae0e9c5-c692-4a4
#     │   9-95a8-550573001207.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/ebc944ab-22d0-485
#     │   6-a95c-668f5e5add3f.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/ee67cd49-aa97-49d
#     │   d-add5-2de6a36b7320.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/ee8d2249-140f-427
#     │   9-83a8-c7810fbab75b.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/f043a5e9-9607-4a9
#     │   3-8687-da78c7054c87.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/f75a0736-2a26-4b6
#     │   d-b6e2-d832620ee7aa.root
#     ├── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#     │   5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/f8dc4c56-49f8-4d6
#     │   b-a88e-73daafce60bf.root
#     └── root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP
#         5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/40000/fe499b18-c0f6-498
#         7-810f-541746a596bd.root
# Output()
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/nanoevents/schemas/fcc.py:5: FutureWarning: In version 2025.1.0 (target date: 2024-12-31 11:59:59-06:00), this will be an error.
# To raise these warnings as errors (and get stack traces to find out where they're called), run
#     import warnings
#     warnings.filterwarnings("error", module="coffea.*")
# after the first `import coffea` or use `@pytest.mark.filterwarnings("error:::coffea.*")` in pytest.
# Issue: coffea.nanoevents.methods.vector will be removed and replaced with scikit-hep vector. Nanoevents schemas internal to coffea will be migrated. Otherwise please consider using that package!.
#   from coffea.nanoevents.methods import vector
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_636/1581751889.py in <module>
#      31         ddc.do_replicas("first", "all")
#      32
# ---> 33         fileset_total = ddc.do_preprocess(output_file=file_name,
#      34             step_size = chunk_size,  #chunk size for files splitting
#      35             align_to_clusters=False,
#
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/dataset_tools/dataset_query.py in do_preprocess(self, output_file, step_size, align_to_clusters, scheduler_url, recalculate_steps, files_per_batch, file_exceptions, save_form, uproot_options, step_size_safety_factor, allow_empty_datasets)
#     679         ):
#     680             with Client(scheduler_url) as ddcsched:
# --> 681                 self.preprocessed_available, self.preprocessed_total = preprocess(
#     682                     self.final_output,
#     683                     step_size=step_size,
#
# /cvmfs/sft-nightlies.cern.ch/lcg/views/devswan/Wed/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/coffea/dataset_tools/preprocess.py in preprocess(fileset, step_size, align_clusters, recalculate_steps, files_per_batch, skip_bad_files, file_exceptions, save_form, scheduler, uproot_options, step_size_safety_factor, allow_empty_datasets)
#     382
#     383             if not allow_empty_datasets:
# --> 384                 raise Exception(ds_empty_msg)
#     385
#     386             warnings.warn(ds_empty_msg)
#
# Exception: There was no populated list of files returned from querying your input dataset.
# Please check your xrootd endpoints, and avoid redirectors.
# Input dataset: /WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/Run3Summer23BPixNanoAODv12-130X_mcRun3_2023_realistic_postBPix_v2-v3/NANOAODSIM
# As parsed for querying: [{'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/00f30420-1d10-4b4a-a03d-455ccc4960e5.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/044ad574-12ce-4037-b1f6-961e7e6993a3.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/065d61e6-4ecd-4932-b635-ee4ffed1f333.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/0a207bdc-9917-4692-9dd1-468881f6c4cc.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/0f0c3ace-fcef-4fe7-a1bf-2a7c967e4667.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/103bcbef-6f7c-4edb-a8d2-ee0b912bf98c.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/10cb9360-d62a-4af9-a93f-aa8aab5a5346.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/12375143-6c90-4637-826c-3d8df01b2b5d.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/12be257c-2f21-4338-b41b-a37c1f23dc22.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/132ee61b-2a8b-455d-8177-7f9a2a3bcc42.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/13eee12c-b338-4cca-8ea8-4afda9231813.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cmsaf.mit.edu:1094//store/mc/Run3Summer23BPixNanoAODv12/WtoLNu-2Jets_PTLNu-100to200_1J_TuneCP5_13p6TeV_amcatnloFXFX-pythia8/NANOAODSIM/130X_mcRun3_2023_realistic_postBPix_v2-v3/2810000/17638198-d917-499f-9c6f-03e53e90da65.root', 'object_path': 'Events', 'steps': None, 'num_entries': None, 'uuid': None}, {'file': 'root://xrootd.cms ...
