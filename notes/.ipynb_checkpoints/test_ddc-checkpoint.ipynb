# %%
from coffea.dataset_tools import rucio_utils
from coffea.dataset_tools.dataset_query import print_dataset_query
from rich.console import Console
from coffea.dataset_tools.dataset_query import DataDiscoveryCLI

ddc = DataDiscoveryCLI()

ddc.do_query("SlepSnu*NanoAOD*v3*")
# Out:
# /usr/local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Wrong Rucio configuration, impossible to create client
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/rucio_utils.py:22, in get_proxy_path()
#      21 try:
# ---> 22     subprocess.run("voms-proxy-info -exists -hours 1", shell=True, check=True)
#      23 except subprocess.CalledProcessError:
#
# File /usr/local/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'voms-proxy-info -exists -hours 1' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 from coffea.dataset_tools.dataset_query import DataDiscoveryCLI
#       6 ddc = DataDiscoveryCLI()
# ----> 8 ddc.do_query("SlepSnu*NanoAOD*v3*")
#
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/dataset_query.py:207, in DataDiscoveryCLI.do_query(self, query)
#     203     query = Prompt.ask(
#     204         "[yellow bold]Query for[/]",
#     205     )
#     206 with self.console.status(f"Querying rucio for: [bold red]{query}[/]"):
# --> 207     outlist, outtree = rucio_utils.query_dataset(
#     208         query,
#     209         client=self.rucio_client,
#     210         tree=True,
#     211         scope="cms",  # TODO configure scope
#     212     )
#     213     # Now let's print the results as a tree
#     214     print_dataset_query(query, outtree, self.console, self.selected_datasets)
#
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/rucio_utils.py:309, in query_dataset(query, client, tree, datatype, scope)
#     287 def query_dataset(
#     288     query: str, client=None, tree: bool = False, datatype="container", scope="cms"
#     289 ):
#     290     """
#     291     This function uses the rucio client to query for containers or datasets.
#     292
#    (...)
#     307
#     308     """
# --> 309     client = client if client else get_rucio_client()
#     310     out = list(
#     311         client.list_dids(
#     312             scope=scope, filters={"name": query, "type": datatype}, long=False
#     313         )
#     314     )
#     315     if tree:
#
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/rucio_utils.py:57, in get_rucio_client(proxy)
#      55 except Exception as e:
#      56     print("Wrong Rucio configuration, impossible to create client")
# ---> 57     raise e
#
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/rucio_utils.py:51, in get_rucio_client(proxy)
#      49 try:
#      50     if not proxy:
# ---> 51         proxy = get_proxy_path()
#      52     nativeClient = Client()
#      53     return nativeClient
#
# File /usr/local/lib/python3.10/site-packages/coffea/dataset_tools/rucio_utils.py:24, in get_proxy_path()
#      22     subprocess.run("voms-proxy-info -exists -hours 1", shell=True, check=True)
#      23 except subprocess.CalledProcessError:
# ---> 24     raise Exception(
#      25         "VOMS proxy expirend or non-existing: please run `voms-proxy-init -voms cms -rfc --valid 168:0`"
#      26     )
#      28 # Now get the path of the certificate
#      29 proxy = subprocess.check_output(
#      30     "voms-proxy-info -path", shell=True, text=True
#      31 ).strip()
#
# Exception: VOMS proxy expirend or non-existing: please run `voms-proxy-init -voms cms -rfc --valid 168:0`
